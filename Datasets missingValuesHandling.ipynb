# dtype: int64

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(nbk.isna())
plt.xlabel('Columns')
plt.ylabel('Rows')
plt.title('Missing Values in Dataset')
plt.show()

# %%
csco = pd.read_csv('CSCO.csv')
csco
# Out:
#             Date       Open       High        Low      Close  Adj Close  \
# 0     1990-02-16   0.000000   0.079861   0.073785   0.077257   0.053231
# 1     1990-02-20   0.000000   0.079861   0.074653   0.079861   0.055025
# 2     1990-02-21   0.000000   0.078993   0.075521   0.078125   0.053829
# 3     1990-02-22   0.000000   0.081597   0.078993   0.078993   0.054427
# 4     1990-02-23   0.000000   0.079861   0.078125   0.078559   0.054128
# ...          ...        ...        ...        ...        ...        ...
# 8486  2023-10-25  53.110001  53.369999  52.330002  52.400002  52.400002
# 8487  2023-10-26  51.869999  52.130001  51.310001  51.369999  51.369999
# 8488  2023-10-27  51.639999  52.150002  51.400002  51.560001  51.560001
# 8489  2023-10-30  51.349998  51.639999  51.090000  51.570000  51.570000
# 8490  2023-10-31  51.750000  52.169998  51.680000  52.130001  52.130001
#
#          Volume
# 0     940636800
# 1     151862400
# 2      70531200
# 3      45216000
# ...

# %%
csco.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  8491.000000  8491.000000  8491.000000  8491.000000  8491.000000
# mean     23.463365    23.759811    23.158570    23.461346    18.432567
# std      16.762119    16.965311    16.546803    16.760438    14.917714
# min       0.000000     0.072917     0.068576     0.071181     0.049044
# 25%      12.302084    12.704166    12.055000    12.270833     8.454725
# 50%      21.290001    21.559999    21.070000    21.270000    14.923951
# 75%      31.425000    31.660000    31.175000    31.468750    24.443344
# max      81.437500    82.000000    79.062500    80.062500    60.169125
#
#              Volume
# count  8.491000e+03
# mean   5.292970e+07
# std    4.108786e+07
# min    8.064000e+05
# 25%    2.673735e+07
# 50%    4.542810e+07
# 75%    6.520570e+07
# max    9.406368e+08

# %%
csco.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
print("google", goog.shape)
print("apple",aapl.shape)
print("amazon",amzn.shape)
print("microsoft", msft.shape)
print("national bank",nbk.shape)
print("cisco",csco.shape)
# Out:
# google (4823, 7)
# apple (10801, 7)
# amazon (6649, 7)
# microsoft (9475, 7)
# national bank (6047, 7)
# cisco (8491, 7)

# %%
goog.corr()
#amzn.corr()
#nbk.corr()
#csco.corr()
#msft.corr()
#aapl.corr()
# Out:
# C:\Users\hasoo\AppData\Local\Temp\ipykernel_14984\475072538.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   goog.corr()
#                Open      High       Low     Close  Adj Close    Volume
# Open       1.000000  0.999901  0.999894  0.999770   0.999770 -0.471242
# High       0.999901  1.000000  0.999872  0.999892   0.999892 -0.470211
# Low        0.999894  0.999872  1.000000  0.999902   0.999902 -0.472559
# Close      0.999770  0.999892  0.999902  1.000000   1.000000 -0.471511
# Adj Close  0.999770  0.999892  0.999902  1.000000   1.000000 -0.471511
# Volume    -0.471242 -0.470211 -0.472559 -0.471511  -0.471511  1.000000

# %%
nbk.isna()
# Out:
#        Date   Open   High    Low  Close  Adj Close  Volume
# 0     False  False  False  False  False      False   False
# 1     False  False  False  False  False      False   False
# 2     False  False  False  False  False      False   False
# 3     False  False  False  False  False      False   False
# 4     False   True   True   True   True       True    True
# ...     ...    ...    ...    ...    ...        ...     ...
# 6042  False  False  False  False  False      False   False
# 6043  False  False  False  False  False      False   False
# 6044  False  False  False  False  False      False   False
# 6045  False  False  False  False  False      False   False
# 6046  False  False  False  False  False      False   False
#
# [6047 rows x 7 columns]

# %%
msft.plot(color='red')
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt
x =goog['Date'];
y =goog['Close'];
plt.figure(figsize=(16,8))
plt.title('the closeing time', fontsize=30)
plt.plot(x,y)
plt.xlabel('Date', fontsize=20)
plt.ylabel('Close Price', fontsize=20)
plt.show()

# %%
plt.figure(figsize=(16,8))

plt.plot(goog['Date'],goog['High'],label='high')
plt.plot(goog['Date'],goog['Low'],label='low')
    
plt.xlabel('Date')
plt.ylabel('dollar /$')
plt.grid(True)
plt.legend()
plt.show()

# %%
nbkX= nbk.iloc[:,1:4]
nbkY=nbk.iloc[:,4:5]
nbkX.head()
# Out:
#        Open      High       Low
# 0  0.221454  0.221454  0.221454
# 1  0.217823  0.217823  0.217823
# 2  0.217823  0.217823  0.214193
# 3  0.217823  0.217823  0.217823
# 4       NaN       NaN       NaN

# %%
nbkY.head()
# Out:
#       Close
# 0  0.221454
# 1  0.217823
# 2  0.217823
# 3  0.217823
# 4       NaN

# %%
nbk['Open'].fillna(nbk['Open'].mean(), inplace=True)
nbk['High'].fillna(nbk['High'].mean(), inplace=True)
nbk['Low'].fillna(nbk['Low'].mean(), inplace=True)
nbk['Volume'].fillna(nbk['Volume'].mean(), inplace=True)

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(nbk.isna())
plt.xlabel('Columns')
plt.ylabel('Rows')
plt.title('Missing Values')
plt.show()

# %%
from sklearn.impute import KNNImputer

#can use 5 or 7 but used 5 for its frequency

imputer = KNNImputer(n_neighbors=5)
nbk['Close'] = imputer.fit_transform(nbk[['Close']])

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(nbk.isna())
plt.xlabel('Columns')
plt.ylabel('Rows')
plt.title('Missing Values')
plt.show()

# %%
missingCounts = nbk.isnull().sum()
sns.barplot(x=missingCounts.index, y=missingCounts)
plt.xticks(rotation=90)
plt.title('MissingCounts')
plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(16,8))

plt.plot(nbk['Date'],nbk['High'],label='high')
plt.plot(nbk['Date'],nbk['Low'],label='low')
    
plt.xlabel('Date')
plt.ylabel('dollar /$')
plt.grid(True)
plt.legend()
plt.show()

# %%
#to_csv() functionnn

nbk2 = pd.read_csv('NBKDEL.csv')
nbk2
# Out:
#            Date      Open      High       Low     Close  Adj Close     Volume
# 0      1/3/2000  0.221454  0.221454  0.221454  0.221454   0.137552    27545.0
# 1      1/4/2000  0.217823  0.217823  0.217823  0.217823   0.135297  1817982.0
# 2      1/5/2000  0.217823  0.217823  0.214193  0.217823   0.135297  2795836.0
# 3      1/6/2000  0.217823  0.217823  0.217823  0.217823   0.135297        0.0
# 4      1/9/2000       NaN       NaN       NaN       NaN        NaN        NaN
# ...         ...       ...       ...       ...       ...        ...        ...
# 5912  3/27/2023  1.007619  1.008571  0.998095  0.999047   0.974271  2737830.0
# 5913  3/28/2023  1.002857  1.009523  0.999047  1.008571   0.983559  4116152.0
# 5914  3/29/2023  1.008571  1.008571  0.999047  1.001904   0.977057  3643277.0
# 5915  3/30/2023  1.057000  1.065000  1.052000  1.056000   1.029812  5053925.0
# 5916   4/2/2023  1.013333  1.027619  1.009523  1.009523   0.984488  2967382.0
#
# [5917 rows x 7 columns]

# %%
# we will take the nbk2 as the nbk dataset cuz i deleted the un normalized numbers

import matplotlib.pyplot as plt
plt.figure(figsize=(16,8))

plt.plot(nbk2['Date'],nbk2['High'],label='high')
plt.plot(nbk2['Date'],nbk2['Low'],label='low')
    
plt.xlabel('Date')
plt.ylabel('dollar /$')
plt.grid(True)
plt.legend()
plt.show()

# %%
nbkX= nbk2.iloc[:,1:4]
nbkY=nbk2.iloc[:,4:5]
nbkX.head()
# Out:
#        Open      High       Low
# 0  0.221454  0.221454  0.221454
# 1  0.217823  0.217823  0.217823
# 2  0.217823  0.217823  0.214193
# 3  0.217823  0.217823  0.217823
# 4       NaN       NaN       NaN

# %%
nbkY.head()
# Out:
#       Close
# 0  0.221454
# 1  0.217823
# 2  0.217823
# 3  0.217823
# 4       NaN

# %%
nbk2['Open'].fillna(nbk2['Open'].mean(), inplace=True)
nbk2['High'].fillna(nbk2['High'].mean(), inplace=True)
nbk2['Low'].fillna(nbk2['Low'].mean(), inplace=True)
nbk2['Volume'].fillna(nbk2['Volume'].mean(), inplace=True)

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(nbk2.isna())
plt.xlabel('Columns')
plt.ylabel('Rows')
plt.title('Missing Values')
plt.show()

# %%
from sklearn.impute import KNNImputer

#can use 5 or 7 but used 5 for its frequency

imputer = KNNImputer(n_neighbors=5)
nbk2['Close'] = imputer.fit_transform(nbk2[['Close']])

# %%
missingCounts = nbk2.isnull().sum()
sns.barplot(x=missingCounts.index, y=missingCounts)
plt.xticks(rotation=90)
plt.title('MissingCounts')
plt.show()

# %%
nbk2.to_csv('NBKFINAL.csv',index='False')

#saved the final nbk dataset

# %%
nbk2.isna().sum()
# Out:
# Date           0
# Open           0
# High           0
# Low            0
# Close          0
# Adj Close    354
# Volume         0
# dtype: int64

# %%
import pandas as pd
nbkf = pd.read_csv('NBKFINAL.csv')
plt.figure(figsize=(16,8))

plt.plot(nbkf['Date'],nbkf['High'],label='high')
plt.plot(nbkf['Date'],nbkf['Low'],label='low')
    
plt.xlabel('Date')
plt.ylabel('dollar /$')
plt.grid(True)
plt.legend()
plt.show()

# %%
fig, axes = plt.subplots(nrows=3, ncols=2)
fig.set_figheight(10)
fig.set_figwidth(15)

# i did it 3 rows and 2 columns

aapl[['Close']].plot(ax=axes[0,0])
axes[0,0].set_title('APPLE')

goog[['Close']].plot(ax=axes[0,1])
axes[0,1].set_title('GOOGLE')

msft[['Close']].plot(ax=axes[1,0])
axes[1,0].set_title('MICROSOFT')

amzn[['Close']].plot(ax=axes[1,1])
axes[1,1].set_title('AMAZON')

nbkf[['Close']].plot(ax=axes[2,0])
axes[2,0].set_title('NATIONAL BANK OF KUWAIT')

csco[['Close']].plot(ax=axes[2,1])
axes[2,1].set_title('CISCO')

fig.tight_layout()

# %%
nbknul = pd.read_csv('NBKDEL.csv')

# %%
from sklearn.impute import KNNImputer

#can use 5 or 7 but used 5 for its frequency

imputer = KNNImputer(n_neighbors=5)
nbknul['Close'].fillna(nbknul['Close'].mean(), inplace=True)
nbknul['Open']= imputer.fit_transform(nbknul[['Open']])
nbknul['High']= imputer.fit_transform(nbknul[['High']])
nbknul['Low']= imputer.fit_transform(nbknul[['Low']])
nbknul['Volume']= imputer.fit_transform(nbknul[['Volume']])

# %%
nbknul[['Close']].plot()
# Out:
# <Axes: >
